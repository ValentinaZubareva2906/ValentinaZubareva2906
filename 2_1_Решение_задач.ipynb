# %% [markdown]
# <a href="https://colab.research.google.com/github/ValentinaZubareva2906/ValentinaZubareva2906/blob/main/2_1_%D0%A0%D0%B5%D1%88%D0%B5%D0%BD%D0%B8%D0%B5_%D0%B7%D0%B0%D0%B4%D0%B0%D1%87.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install openai langchain langchain-openai langchain-community -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 262.9/262.9 kB 2.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 810.5/810.5 kB 6.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 9.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 12.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 4.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 269.1/269.1 kB 11.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.6/71.6 kB 4.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 3.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.8/77.8 kB 5.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 4.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 4.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.5/138.5 kB 2.8 MB/s eta 0:00:00

# %%
# !curl ipinfo.io
# Out:
# {
#   "ip": "35.196.197.5",
#   "hostname": "5.197.196.35.bc.googleusercontent.com",
#   "city": "North Charleston",
#   "region": "South Carolina",
#   "country": "US",
#   "loc": "32.8546,-79.9748",
#   "org": "AS396982 Google LLC",
#   "postal": "29415",
#   "timezone": "America/New_York",
#   "readme": "https://ipinfo.io/missingauth"
# }

# %%
# !pip install langchain_google_genai

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

gemini_chat = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    temperature=0,
    api_key="AIzaSyBbPRq1_u9O3h45R9G8sVlPWMChbxp5KGA"
)

# %% [markdown]
# ## Если используете ключ от OpenAI, запустите эту ячейку 👇

# %%
from langchain_openai import ChatOpenAI
import os
from getpass import getpass


# os.environ['OPENAI_API_KEY'] = "Введите ваш OpenAI API ключ"
os.environ['OPENAI_API_KEY'] = getpass(prompt='Введите ваш OpenAI API ключ')

# Инициализируем языковую модель
llm = ChatOpenAI(temperature=0.0)

# %% [markdown]
# ## Если используете ключ из курса, запустите эти ячейки 👇

# %%
from langchain_openai import ChatOpenAI
from getpass import getpass

#course_api_key= "Введите ваш API ключ с курса"
course_api_key = getpass(prompt='Введите API ключ')

# Инициализируем языковую модель
llm = ChatOpenAI(api_key=course_api_key, model='gpt-4o-mini',
                 base_url="https://aleron-llm.neuraldeep.tech/")

# %% [markdown]
# ## Задание 2.1.8 LLM — сила 💪, ML — могила 🧟

# %%
import pandas as pd
from tqdm import tqdm

# %%
df = pd.read_csv('https://stepik.org/media/attachments/lesson/1084297/submission100lines.csv')

# %%
df.head()
# Out:
#    amount    text_id                                               text
# 0       2   14205200  Сниму жилье. 500-600 рублей сутки. Эконом клас...
# 1       6  319097075  ищем жилье в центре недалеко от моря с 23.07-0...
# 2       4   98881311  Ищем жилье на период с 18-28июля..на две семьи...
# 3       4   44587027  2 семьи по 3 человека (2 взрослых и ребенок) с...
# 4       3  352802829  Сниму недорогое жилье в лазаревском на 6 чел 3...

# %%
# Напишите шаблон промпта, указав инструкцию, вопрос и выходной индикатор

prompt_template = """Ответь на вопрос используя информацию из контекста
Если на вопрос нельзя ответить, то ответь 0.

Context: {text_input}

Question: Посчитай количество человек в числовом формате int.

Answer: ...
"""

# %%
amount_list = [] # Список, где будем хранить ответы модели

for text_input in tqdm(df['text']):
    prompt = prompt_template.format(text_input=text_input) # Добавляем сообщение в промпт
    amount = gemini_chat.invoke(prompt).content # Ответ модели
    amount_list.append(amount) # Добавляем ответ в список
    #break # Для отладки. Уберите, когда убедитесь, что на одном примере работает
# Out:
#  14%|█▍        | 14/100 [00:20<01:52,  1.31s/it]WARNING:langchain_google_genai.chat_models:Retrying langchain_google_genai.chat_models._chat_with_retry.<locals>._chat_with_retry in 2.0 seconds as it raised ResourceExhausted: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 10
# Please retry in 18.447112158s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 10
# }
# , links {
# ...

# %%
amount_list = [] # Список, где будем хранить ответы модели

for text_input in tqdm(df['text']):
    prompt = prompt_template.format(text_input=text_input) # Добавляем сообщение в промпт
    amount = llm.invoke(prompt).content # Ответ модели
    amount_list.append(amount) # Добавляем ответ в список
    break # Для отладки. Уберите, когда убедитесь, что на одном примере работает

# %%
# перед записью ответа в датафрейм, проверьте какого типа ответы
type(amount_list[0])
# Out:
# str

# %%
print(amount_list)
# Out:
# ['1', '5', '7', '6', '6', '2', '0', '4', '4', '3', '4', '3', '5', '5', '6', '4', '2', '4', '2', '6', '3', '4', '2', '4', '3', '2', '6', '3', '4', '3', '6', '2', '4', '4', '8', '1', '3', '2', '2', '3', '4', '3', '3', '3', '6', '2', '3', '4', '4', '3', '3', '3', '4', '4', '4', '2', '2', '2', '2', '2', '3', '4', '11', '2', '3', '2', '2', '5', '3', '4', '3', '2', '3', '2', '2', '4', '5', '0', '3', '1', '4', '4', '4', '1', '2', '7', '5', '4', '3', '3', '7', '5', '5', '4', '12', '9', '1', '2', '2', '3']

# %%
print([int(x) for x in amount_list])
# Out:
# [1, 5, 7, 6, 6, 2, 0, 4, 4, 3, 4, 3, 5, 5, 6, 4, 2, 4, 2, 6, 3, 4, 2, 4, 3, 2, 6, 3, 4, 3, 6, 2, 4, 4, 8, 1, 3, 2, 2, 3, 4, 3, 3, 3, 6, 2, 3, 4, 4, 3, 3, 3, 4, 4, 4, 2, 2, 2, 2, 2, 3, 4, 11, 2, 3, 2, 2, 5, 3, 4, 3, 2, 3, 2, 2, 4, 5, 0, 3, 1, 4, 4, 4, 1, 2, 7, 5, 4, 3, 3, 7, 5, 5, 4, 12, 9, 1, 2, 2, 3]

# %%
# Чтобы система зачла ответы на Степике, надо перевести их в числа
# Если не знаете как, спросите у ChatGPT)

# %%
df['amount'] = [int(x) for x in amount_list] # Создаём новый столбец из ответов модели

# %%
df.to_csv('2_1_8_solution.csv', index=False) # Сохраняем файл, отправляем на Stepik, получаем баллы :)
